# %% [markdown]
# ### Day 23: 30 Days of python programming
#
# #### Virtual Environment

# %% [markdown]
# Check the installed python library in windows

# %% [markdown]
# ```
# >>> pip freeze
# beautifulsoup4==4.13.4
# certifi==2025.7.14
# charset-normalizer==3.4.2
# html5lib==1.1
# idna==3.10
# lxml==6.0.0
# pandas==2.3.1
# python-dateutil==2.9.0.post0
# pytz==2025.2
# requests==2.32.4
# six==1.17.0
# soupsieve==2.7
# typing_extensions==4.14.1
# tzdata==2025.2
# urllib3==2.5.0
# webencodings==0.5.1

# %% [markdown]
# Install virtualenv

# %% [markdown]
# ```
# >>> pip install virtualenv
# Successfully installed distlib-0.4.0 filelock-3.18.0 platformdirs-4.3.8 virtualenv-20.32.0

# %% [markdown]
# Create virtual env with any name (here name is "venv"):

# %% [markdown]
# ```
# >>> python -m venv venv

# %% [markdown]
# To activate virtual environment

# %% [markdown]
# ```
# >>> .\venv\Scripts\activate
# (venv) PS C:... >

# %% [markdown]
# Installing Django package in venv

# %% [markdown]
# ```
# >>> pip install Django
# >>> pip freeze
# asgiref==3.9.1
# Django==5.2.4
# sqlparse==0.5.3
# typing_extensions==4.14.1
# tzdata==2025.2

# %% [markdown]
# Installing Flask in venv

# %% [markdown]
# ```
# >>> pip install flask
# >>> pip freeze
# asgiref==3.9.1
# blinker==1.9.0
# click==8.2.1
# colorama==0.4.6
# Django==5.2.4
# Flask==3.1.1
# itsdangerous==2.2.0
# Jinja2==3.1.6
# MarkupSafe==3.0.2
# sqlparse==0.5.3
# typing_extensions==4.14.1
# tzdata==2025.2
# Werkzeug==3.1.3

# %% [markdown]
# To deactivate venv

# %% [markdown]
# ```
# (venv) PS > deactivate
# PS >

# %% [markdown]
# To delete virtual env

# %% [markdown]
# ```
# >>> rmdir /s /q venv
